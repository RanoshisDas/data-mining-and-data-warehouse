# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C:/Users/USER/Documents/Ranoshis Das/data/data.csv' )
df.plot()
plt.show()

# %%
df.plot(kind='bar',x='Height',y='Weight')
plt.show()
